# %%
from random import random
from numpy import arange
from matplotlib import pyplot as plt
import numpy as np

# %%
#a) 3 doors

cmax = 1000
h = 1
sw = 0
sl = 0
tw = 0
tl = 0

wpoints = arange(0, cmax, h)
#Switch_Won = []
#Switch_Lost = []
#Stay_Won = []
#Stay_Lost = []

for w in wpoints:
    for d in range(1):
        correct = np.random.randint(1, 4)
        #print(correct)
        initial_choice = np.random.randint(1,4)
        #print(initial_choice)
        if correct == 1 and initial_choice == 1:
            opened = np.random.choice([2,3])
            new_choice = np.random.choice([0,1])
            if new_choice == 1:
                tw += 1
            elif new_choice == 0:
                sl += 1
        elif correct == 2 and initial_choice == 2:
            opened = np.random.choice([1,3]) 
            new_choice = np.random.choice([0,2])
            if new_choice == 2:
                tw += 1
            elif new_choice == 0:
                sl += 1
        elif correct == 3 and initial_choice == 3:
            opened = np.random.choice([1,2]) 
            new_choice = np.random.choice([0,3])
            if new_choice == 3:
                tw += 1
            elif new_choice == 0:
                sl += 1

        elif correct == 1 and initial_choice == 2:
            opened = 3
            new_choice = np.random.choice([1,2])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
        elif correct == 1 and initial_choice == 3:
            opened = 2
            new_choice = np.random.choice([1,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 3:
                tl += 1

            
        elif correct == 2 and initial_choice == 1:
            opened = 3
            new_choice = np.random.choice([1,2])
            if new_choice == 2:
                sw += 1
            elif new_choice == 1:
                tl += 1
        elif correct == 2 and initial_choice == 3:
            opened = 1 
            new_choice = np.random.choice([2,3])
            if new_choice == 2:
                sw += 1
            elif new_choice == 3:
                tl += 1
                
                
        elif correct == 3 and initial_choice == 1:
            opened = 2 
            new_choice = np.random.choice([1,3])
            if new_choice == 1:
                tl += 1
            elif new_choice == 3:
                sw += 1
        elif correct == 3 and initial_choice == 2:
            opened = 1  
            new_choice = np.random.choice([2,3])
            if new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sw += 1
                
#        Switch_Won.append(sw)
#        Switch_Lost.append(sl)
#        Stay_Won.append(tw)
#        Stay_Lost.append(tl)

        #print(sw, sl, tw, tl)
#print(Switch_Won, Switch_Lost, Stay_Won, Stay_Lost)

sw_prob = sw/(sw+sl)
tw_prob = tw/(tl+tw)

 
print("If the player switches, the percentage of times they win is ",sw_prob, ". If the player stays,  the percentage of times they win is ", tw_prob, '.')
# Out:
# 0.6699604743083004 0.3157894736842105
# If the player switches, the percentage of times they win is  0.6699604743083004 . If the player stays,  the percentage of times they win is  0.3157894736842105 .

# %%
#b) 4 doors

cmax = 1000
h = 1
sw = 0
sl = 0
tw = 0
tl = 0

wpoints = arange(0, cmax, h)
#Switch_Won = []
#Switch_Lost = []
#Stay_Won = []
#Stay_Lost = []

for w in wpoints:
    for d in range(1):
        correct = np.random.randint(1, 5)
        initial_choice = np.random.randint(1,5)
        if correct == 1 and initial_choice == 1:
            new_choice = np.random.choice([0,1,2])
            if new_choice == 0:
                tw += 1
            elif new_choice == 1 or 2:
                sl += 1
        elif correct == 2 and initial_choice == 2: 
            new_choice = np.random.choice([0,1,2])
            if new_choice == 0:
                tw += 1
            elif new_choice == 1 or 2:
                sl += 1
        elif correct == 3 and initial_choice == 3:
            new_choice = np.random.choice([0,1,2])
            if new_choice == 0:
                tw += 1
            elif new_choice == 1 or 2:
                sl += 1
        elif correct == 4 and initial_choice == 4: 
            new_choice = np.random.choice([0,1,2])
            if new_choice == 0:
                tw += 1
            elif new_choice == 1 or 2:
                sl += 1

        elif correct == 1 and initial_choice == 2:
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 1 and initial_choice == 3:
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 3:
                tl += 1
            elif new_choice == 2:
                sl += 1
        elif correct == 1 and initial_choice == 4:
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1

            
        elif correct == 2 and initial_choice == 1:
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 2 and initial_choice == 3: 
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 2 and initial_choice == 4: 
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
                
        elif correct == 3 and initial_choice == 1:
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 3 and initial_choice == 2: 
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 2 and initial_choice == 3: 
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
                
        elif correct == 4 and initial_choice == 1:
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 4 and initial_choice == 2: 
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
        elif correct == 4 and initial_choice == 3: 
            new_choice = np.random.choice([1,2,3])
            if new_choice == 1:
                sw += 1
            elif new_choice == 2:
                tl += 1
            elif new_choice == 3:
                sl += 1
                
sw_prob = sw/(sw+sl)
tw_prob = tw/(tl+tw)

print("If the player switches, the percentage of times they win is ",sw_prob, ". If the player stays,  the percentage of times they win is ", tw_prob, '.')
# Out:
# If the player switches, the percentage of times they win is  0.3466453674121406 . If the player stays,  the percentage of times they win is  0.30094043887147337 .

# %% [raw]
# For both 3 door and 4 door, you had a higher percentage of wins i
